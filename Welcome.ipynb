# %% [markdown]
# # Welcome to the Python for Geosciences Course!
#
# This interactive environment contains all the practical exercises (TPs) and corrections for the course.
# To access all files, click on the folder icon at the top left corner of the page.
#
# ## 📚 Practical Exercises (TPs)
#
# - [**Pandas TP**](TPs/notebooks/TP_pandas.ipynb): Data analysis for geosciences with pandas.
# - [**Xarray TP**](TPs/notebooks/TP_xarray.ipynb): Multidimensional arrays and NetCDF data with xarray.
#
# ## 📝 Corrections
#
# - [**Pandas Corrections**](TPs/notebooks_corrections/TP_pandas_corrections.ipynb)
# - [**Xarray Corrections**](TPs/notebooks_corrections/TP_xarray_corrections.ipynb)
# - [**Dask Demo**](TPs/notebooks_corrections/Dask_demo.ipynb)
#
# ## 📂 Data
# The datasets are located in the `TPs/data` directory and have been pre-downloaded via the `postBuild` script for your convenience.
